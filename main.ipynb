# %%
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
import pandas as pd
import io
import os
import datetime
import config
import encoding_decoding
from sqlalchemy import create_engine
import blob_helper

# %%
#Engine to upload dataframe to empty table in mysql
engine = create_engine(config.engine)

# %%
#creating container in azure storage
blob_helper.create_container(config.container_name)
# Out:
# 'container created'

# %%
#uploading file to azure storage container
file_to_upload = "aman.txt"
blob_helper.upload_file(config.container_name, file_to_upload, "aman.txt")
# Out:
# 'file uploaded successfully'

# %%
# List all containers in the storage account
blob_helper.list_container_name()
# Out:
# sales-project

# %%
#list all blobs inside a container
blob_helper.list_blob_in_container(config.container_name)
# Out:
# aman.txt
# customers_datamart.csv
# sales_data
# sales_data.csv
# sales_team_datamart.csv

# %%
#check if file is present or not in local directory
directory_path = config.sales_dir_path
csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

# %%
if csv_files:
    print("CSV files found in the directory:")
    for csv_file in csv_files:
        print(csv_file)
else:
    print("No CSV files found in the directory.")
# Out:
# CSV files found in the directory:
# sales_data.csv

# %%
# Upload a file to the container
f_to_upload = directory_path+"\\"+csv_file
blob_helper.upload_file(config.container_name,f_to_upload,"sales_data.csv")
# Out:
# 'file uploaded successfully'

# %%
#Download same file to local storage
csv_file_name = config.master_file_name
df = blob_helper.read_csv_from_blob(config.container_name, csv_file_name)

# %%
df.head()
# Out:
#    customer_id  store_id product_name  sales_date  sales_person_id  price  \
# 0           19       123  clinic plus  2023-04-03                9    1.5
# 1            2       122        maida  2023-05-11                6   20.0
# 2           15       122    dantkanti  2023-07-04                4  100.0
# 3            8       122        maida  2023-08-07                6   20.0
# 4           17       121        sugar  2023-05-03                1   50.0
#
#    quantity  total_cost
# 0         7        10.5
# 1         4        80.0
# 2         2       200.0
# 3         1        20.0
# 4        10       500.0

# %%
# MySQL database connection parameters
host = config.host
user = config.user
password = config.password
database = config.database

# %%
# Create a MySQL database connection
connection = blob_helper.get_mysql_connection()

# %%
#mysql to dataframe
def load(table_name):
    query = f"SELECT * FROM "+table_name
    return query

# %%
# Query to retrieve data from the MySQL table
#query = f"SELECT * FROM product"
# Read data into a Pandas DataFrame
df_store = pd.read_sql(load("store"), connection)
df_cust = pd.read_sql(load("customer"), connection)
df_sales = pd.read_sql(load("sales_team"), connection)
df_prod = pd.read_sql(load("product"), connection)
# Out:
# C:\Users\aman.ab.srivastava\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\aman.ab.srivastava\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\aman.ab.srivastava\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\aman.ab.srivastava\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df_cust.head()
# Out:
#    customer_id first_name last_name address pincode phone_number  \
# 0            1     Saanvi   Krishna   Delhi  122009   9173121081
# 1            2    Dhanush     Sahni   Delhi  122009   9155328165
# 2            3     Yasmin      Shan   Delhi  122009   9191478300
# 3            4      Vidur    Mammen   Delhi  122009   9119017511
# 4            5     Shamik    Doctor   Delhi  122009   9105180499
#
#   customer_joining_date
# 0            2021-01-20
# 1            2022-03-27
# 2            2023-04-08
# 3            2020-10-12
# 4            2022-10-30

# %%
df_sales.head()
# Out:
#    id first_name last_name  manager_id is_manager address pincode joining_date
# 0   1      Rahul     Verma          10          N   Delhi  122007   2020-05-01
# 1   2      Priya     Singh          10          N   Delhi  122007   2020-05-01
# 2   3       Amit    Sharma          10          N   Delhi  122007   2020-05-01
# 3   4      Sneha     Gupta          10          N   Delhi  122007   2020-05-01
# 4   5       Neha     Kumar          10          N   Delhi  122007   2020-05-01

# %%
df_prod.head()
# Out:
#    id         name  current_price  old_price created_date updated_date  \
# 0   1  quaker oats          212.0      212.0   2022-05-15         None
# 1   2        sugar           50.0       50.0   2021-08-10         None
# 2   3        maida           20.0       20.0   2023-03-20         None
# 3   4        besan           52.0       52.0   2020-05-05         None
# 4   5  refined oil          110.0      110.0   2022-01-15         None
#
#   expiry_date
# 0  2025-01-01
# 1  2025-01-01
# 2  2025-01-01
# 3  2025-01-01
# 4  2025-01-01

# %%
df.head()
# Out:
#    customer_id  store_id product_name  sales_date  sales_person_id  price  \
# 0           19       123  clinic plus  2023-04-03                9    1.5
# 1            2       122        maida  2023-05-11                6   20.0
# 2           15       122    dantkanti  2023-07-04                4  100.0
# 3            8       122        maida  2023-08-07                6   20.0
# 4           17       121        sugar  2023-05-03                1   50.0
#
#    quantity  total_cost
# 0         7        10.5
# 1         4        80.0
# 2         2       200.0
# 3         1        20.0
# 4        10       500.0

# %%
res_df= pd.merge(df, df_cust, on= 'customer_id', how='inner')
res_df= pd.merge(res_df, df_prod , left_on= 'product_name',right_on = 'name', how='inner')

# %%
res_df= pd.merge(res_df, df_sales , left_on= 'sales_person_id',right_on = 'id', how='inner')

# %%
res_df.head()
# Out:
#    customer_id  store_id product_name  sales_date  sales_person_id  price  \
# 0           19       123  clinic plus  2023-04-03                9    1.5
# 1            7       123  clinic plus  2023-04-05                9    1.5
# 2            1       123  clinic plus  2023-06-11                9    1.5
# 3           18       123  clinic plus  2023-08-16                9    1.5
# 4            5       123  clinic plus  2023-06-15                9    1.5
#
#    quantity  total_cost first_name_x last_name_x  ... updated_date  \
# 0         7        10.5     Indranil       Dutta  ...         None
# 1         6         9.0        Romil     Shanker  ...         None
# 2         9        13.5       Saanvi     Krishna  ...         None
# 3         3         4.5    Vardaniya        Jani  ...         None
# 4         1         1.5       Shamik      Doctor  ...         None
#
#   expiry_date id_y first_name_y  last_name_y manager_id  is_manager  \
# 0  2025-01-01    9       Monica         Jain         10           N
# 1  2025-01-01    9       Monica         Jain         10           N
# 2  2025-01-01    9       Monica         Jain         10           N
# 3  2025-01-01    9       Monica         Jain         10           N
# 4  2025-01-01    9       Monica         Jain         10           N
#
#    address_y pincode_y joining_date
# 0      Delhi    122007   2020-05-01
# 1      Delhi    122007   2020-05-01
# 2      Delhi    122007   2020-05-01
# 3      Delhi    122007   2020-05-01
# 4      Delhi    122007   2020-05-01
#
# [5 rows x 29 columns]

# %%
df_store
# Out:
#     id address store_pincode store_manager_name store_opening_date  \
# 0  121   Delhi        122009             Manish         2022-01-15
# 1  122   Delhi        110011             Nikita         2021-08-10
# 2  123   Delhi        201301             vikash         2023-01-20
# 3  124   Delhi        400001             Rakesh         2020-05-05
#
#                               reviews
# 0  Great store with a friendly staff.
# 1    Excellent selection of products.
# 2          Clean and organized store.
# 3      Good prices and helpful staff.

# %%
res_df= pd.merge(res_df, df_store , left_on= 'store_id',right_on = 'id', how='inner')

# %%
res_df.head()
# Out:
#    customer_id  store_id product_name  sales_date  sales_person_id  price  \
# 0           19       123  clinic plus  2023-04-03                9    1.5
# 1            7       123  clinic plus  2023-04-05                9    1.5
# 2            1       123  clinic plus  2023-06-11                9    1.5
# 3           18       123  clinic plus  2023-08-16                9    1.5
# 4            5       123  clinic plus  2023-06-15                9    1.5
#
#    quantity  total_cost first_name_x last_name_x  ... is_manager address_y  \
# 0         7        10.5     Indranil       Dutta  ...          N     Delhi
# 1         6         9.0        Romil     Shanker  ...          N     Delhi
# 2         9        13.5       Saanvi     Krishna  ...          N     Delhi
# 3         3         4.5    Vardaniya        Jani  ...          N     Delhi
# 4         1         1.5       Shamik      Doctor  ...          N     Delhi
#
#   pincode_y joining_date   id address  store_pincode  store_manager_name  \
# 0    122007   2020-05-01  123   Delhi         201301              vikash
# 1    122007   2020-05-01  123   Delhi         201301              vikash
# 2    122007   2020-05-01  123   Delhi         201301              vikash
# 3    122007   2020-05-01  123   Delhi         201301              vikash
# 4    122007   2020-05-01  123   Delhi         201301              vikash
#
#   store_opening_date                     reviews
# 0         2023-01-20  Clean and organized store.
# 1         2023-01-20  Clean and organized store.
# 2         2023-01-20  Clean and organized store.
# 3         2023-01-20  Clean and organized store.
# 4         2023-01-20  Clean and organized store.
#
# [5 rows x 35 columns]

# %%
res_df.columns
# Out:
# Index(['customer_id', 'store_id', 'product_name', 'sales_date',
#        'sales_person_id', 'price', 'quantity', 'total_cost', 'first_name_x',
#        'last_name_x', 'address_x', 'pincode_x', 'phone_number',
#        'customer_joining_date', 'id_x', 'name', 'current_price', 'old_price',
#        'created_date', 'updated_date', 'expiry_date', 'id_y', 'first_name_y',
#        'last_name_y', 'manager_id', 'is_manager', 'address_y', 'pincode_y',
#        'joining_date', 'id', 'address', 'store_pincode', 'store_manager_name',
#        'store_opening_date', 'reviews'],
#       dtype='object')

# %%
col= ['customer_id','first_name_x','last_name_x','store_id','address','store_pincode','store_manager_name','product_name','current_price','expiry_date','sales_date','sales_person_id','first_name_y','last_name_y','joining_date','price','quantity','total_cost']

# %%
res_df= res_df[col]

# %%
res_df.head()
# Out:
#    customer_id first_name_x last_name_x  store_id address store_pincode  \
# 0           19     Indranil       Dutta       123   Delhi        201301
# 1            7        Romil     Shanker       123   Delhi        201301
# 2            1       Saanvi     Krishna       123   Delhi        201301
# 3           18    Vardaniya        Jani       123   Delhi        201301
# 4            5       Shamik      Doctor       123   Delhi        201301
#
#   store_manager_name product_name  current_price expiry_date  sales_date  \
# 0             vikash  clinic plus            1.5  2025-01-01  2023-04-03
# 1             vikash  clinic plus            1.5  2025-01-01  2023-04-05
# 2             vikash  clinic plus            1.5  2025-01-01  2023-06-11
# 3             vikash  clinic plus            1.5  2025-01-01  2023-08-16
# 4             vikash  clinic plus            1.5  2025-01-01  2023-06-15
#
#    sales_person_id first_name_y last_name_y joining_date  price  quantity  \
# 0                9       Monica        Jain   2020-05-01    1.5         7
# 1                9       Monica        Jain   2020-05-01    1.5         6
# 2                9       Monica        Jain   2020-05-01    1.5         9
# 3                9       Monica        Jain   2020-05-01    1.5         3
# 4                9       Monica        Jain   2020-05-01    1.5         1
#
#    total_cost
# 0        10.5
# 1         9.0
# 2        13.5
# 3         4.5
# 4         1.5

# %%
df.to_csv(config.master_dir+"\\master_df.csv", index=False)

# %%
#Basic Transformation 1
df.head()
# Out:
#    customer_id  store_id product_name  sales_date  sales_person_id  price  \
# 0           19       123  clinic plus  2023-04-03                9    1.5
# 1            2       122        maida  2023-05-11                6   20.0
# 2           15       122    dantkanti  2023-07-04                4  100.0
# 3            8       122        maida  2023-08-07                6   20.0
# 4           17       121        sugar  2023-05-03                1   50.0
#
#    quantity  total_cost
# 0         7        10.5
# 1         4        80.0
# 2         2       200.0
# 3         1        20.0
# 4        10       500.0

# %%
df['month'] = -1
for i in range(len(df)):
    df['month'][i] = datetime.datetime.strptime(df['sales_date'][i], "%Y-%m-%d").month
# Out:
# C:\Users\aman.ab.srivastava\AppData\Local\Temp\ipykernel_14848\1833660722.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'][i] = datetime.datetime.strptime(df['sales_date'][i], "%Y-%m-%d").month

# %%
df.head()
# Out:
#    customer_id  store_id product_name  sales_date  sales_person_id  price  \
# 0           19       123  clinic plus  2023-04-03                9    1.5
# 1            2       122        maida  2023-05-11                6   20.0
# 2           15       122    dantkanti  2023-07-04                4  100.0
# 3            8       122        maida  2023-08-07                6   20.0
# 4           17       121        sugar  2023-05-03                1   50.0
#
#    quantity  total_cost  month
# 0         7        10.5      4
# 1         4        80.0      5
# 2         2       200.0      7
# 3         1        20.0      8
# 4        10       500.0      5

# %%
# Group by customer_id and month, and calculate the total sales
result = df.groupby(['customer_id', 'month']).agg(
    total_sales=pd.NamedAgg(column='price', aggfunc='sum'),
    store_id=pd.NamedAgg(column='store_id', aggfunc='first'),
    product_name=pd.NamedAgg(column='product_name', aggfunc='first'),
    sales_person_id=pd.NamedAgg(column='sales_person_id', aggfunc='first'),
    quantity=pd.NamedAgg(column='quantity', aggfunc='first')
).reset_index()

# %%
result.head()
# Out:
#    customer_id  month  total_sales  store_id product_name  sales_person_id  \
# 0            1      3        222.0       122        sugar                5
# 1            1      4        395.0       123    dantkanti                7
# 2            1      5        312.0       123    dantkanti                7
# 3            1      6        415.0       123  clinic plus                7
# 4            1      7        123.5       123        besan                8
#
#    quantity
# 0         3
# 1         3
# 2         4
# 3         3
# 4         2

# %%
#push this to mysql as customer_data_mart

# %%
cust_dm = pd.merge(result,df_cust, on='customer_id', how = 'inner')

# %%
cust_dm['full_name'] = cust_dm['first_name']+' '+cust_dm['last_name']

# %%
cust_dm.head()
# Out:
#    customer_id  month  total_sales  store_id product_name  sales_person_id  \
# 0            1      3        222.0       122        sugar                5
# 1            1      4        395.0       123    dantkanti                7
# 2            1      5        312.0       123    dantkanti                7
# 3            1      6        415.0       123  clinic plus                7
# 4            1      7        123.5       123        besan                8
#
#    quantity first_name last_name address pincode phone_number  \
# 0         3     Saanvi   Krishna   Delhi  122009   9173121081
# 1         3     Saanvi   Krishna   Delhi  122009   9173121081
# 2         4     Saanvi   Krishna   Delhi  122009   9173121081
# 3         3     Saanvi   Krishna   Delhi  122009   9173121081
# 4         2     Saanvi   Krishna   Delhi  122009   9173121081
#
#   customer_joining_date       full_name
# 0            2021-01-20  Saanvi Krishna
# 1            2021-01-20  Saanvi Krishna
# 2            2021-01-20  Saanvi Krishna
# 3            2021-01-20  Saanvi Krishna
# 4            2021-01-20  Saanvi Krishna

# %%
cust_dm.columns
# Out:
# Index(['customer_id', 'month', 'total_sales', 'store_id', 'product_name',
#        'sales_person_id', 'quantity', 'first_name', 'last_name', 'address',
#        'pincode', 'phone_number', 'customer_joining_date', 'full_name'],
#       dtype='object')

# %%
cust_dm = cust_dm[['customer_id','full_name', 'address','phone_number','month', 'total_sales']]

# %%
cust_dm = cust_dm.rename(columns = {'month_x': 'sales_date_month'})

# %%
cust_dm.head()
# Out:
#    customer_id       full_name address phone_number  month  total_sales
# 0            1  Saanvi Krishna   Delhi   9173121081      3        222.0
# 1            1  Saanvi Krishna   Delhi   9173121081      4        395.0
# 2            1  Saanvi Krishna   Delhi   9173121081      5        312.0
# 3            1  Saanvi Krishna   Delhi   9173121081      6        415.0
# 4            1  Saanvi Krishna   Delhi   9173121081      7        123.5

# %%
cust_dm.to_sql('customers_data_mart', con=engine, if_exists='replace', index=False)
# Out:
# 118

# %%
#Basic Transformation 2
df_sales.head()
# Out:
#    id first_name last_name  manager_id is_manager address pincode joining_date
# 0   1      Rahul     Verma          10          N   Delhi  122007   2020-05-01
# 1   2      Priya     Singh          10          N   Delhi  122007   2020-05-01
# 2   3       Amit    Sharma          10          N   Delhi  122007   2020-05-01
# 3   4      Sneha     Gupta          10          N   Delhi  122007   2020-05-01
# 4   5       Neha     Kumar          10          N   Delhi  122007   2020-05-01

# %%
result2 = df.groupby(['store_id','sales_person_id','month']).agg(
    total_sales=pd.NamedAgg(column='price', aggfunc='sum'),
    customer_id=pd.NamedAgg(column='customer_id', aggfunc='sum'),
    #store_id=pd.NamedAgg(column='store_id', aggfunc='first'),
    product_name=pd.NamedAgg(column='product_name', aggfunc='first'),
    quantity=pd.NamedAgg(column='quantity', aggfunc='first')
).reset_index()

# %%
result2.head()
# Out:
#    store_id  sales_person_id  month  total_sales  customer_id product_name  \
# 0       121                1      3        206.5           53  clinic plus
# 1       121                1      4        535.0          100  refined oil
# 2       121                1      5        768.0          118        sugar
# 3       121                1      6       1261.5          101  clinic plus
# 4       121                1      7        650.0           94    dantkanti
#
#    quantity
# 0         4
# 1         5
# 2        10
# 3         4
# 4         8

# %%
result2[result2.store_id == 121]
# Out:
#     store_id  sales_person_id  month  total_sales  customer_id product_name  \
# 0        121                1      3        206.5           53  clinic plus
# 1        121                1      4        535.0          100  refined oil
# 2        121                1      5        768.0          118        sugar
# 3        121                1      6       1261.5          101  clinic plus
# 4        121                1      7        650.0           94    dantkanti
# 5        121                1      8       1160.0           93  quaker oats
# 6        121                2      3        786.0           74        maida
# 7        121                2      4        805.5           97  quaker oats
# 8        121                2      5        604.0           86  refined oil
# 9        121                2      6        726.0           83     nutrella
# 10       121                2      7        833.0          178    dantkanti
# 11       121                2      8        402.0           49    dantkanti
# 12       121                3      3        396.0           78     nutrella
# 13       121                3      4        819.5          123        besan
# 14       121                3      5        790.0          116     nutrella
# 15       121                3      6        908.0           97        sugar
# 16       121                3      7       1546.5          140  quaker oats
# 17       121                3      8        273.0           94        sugar
#
#     quantity
# 0          4
# 1          5
# 2         10
# 3          4
# 4          8
# 5          3
# 6          1
# 7         10
# 8          9
# 9          7
# 10         7
# 11         7
# 12         8
# 13         3
# 14         4
# 15        10
# 16        10
# 17         2

# %%
# Calculate the salesperson with the most sales per store_id and month
max_sales_person = result2.groupby(['store_id', 'month'])['total_sales'].idxmax()
result2['bonus'] = 0.01 * result2['total_sales'] * result2.index.isin(max_sales_person).astype(int)

# %%
result2
# Out:
#     store_id  sales_person_id  month  total_sales  customer_id product_name  \
# 0        121                1      3        206.5           53  clinic plus
# 1        121                1      4        535.0          100  refined oil
# 2        121                1      5        768.0          118        sugar
# 3        121                1      6       1261.5          101  clinic plus
# 4        121                1      7        650.0           94    dantkanti
# 5        121                1      8       1160.0           93  quaker oats
# 6        121                2      3        786.0           74        maida
# 7        121                2      4        805.5           97  quaker oats
# 8        121                2      5        604.0           86  refined oil
# 9        121                2      6        726.0           83     nutrella
# 10       121                2      7        833.0          178    dantkanti
# 11       121                2      8        402.0           49    dantkanti
# 12       121                3      3        396.0           78     nutrella
# 13       121                3      4        819.5          123        besan
# 14       121                3      5        790.0          116     nutrella
# 15       121                3      6        908.0           97        sugar
# 16       121                3      7       1546.5          140  quaker oats
# 17       121                3      8        273.0           94        sugar
# 18       122                4      3        709.5           58  quaker oats
# 19       122                4      4        797.0          124  clinic plus
# 20       122                4      5        262.0           49        sugar
# 21       122                4      6        616.5          124        sugar
# 22       122                4      7        847.0          186    dantkanti
# 23       122                4      8        321.5           38    dantkanti
# 24       122                5      3        732.0          115        maida
# 25       122                5      4        203.5           51  clinic plus
# 26       122                5      5        426.0           54        sugar
# 27       122                5      6        813.5          144  clinic plus
# 28       122                5      7        727.5           83  quaker oats
# 29       122                5      8        576.0           38  quaker oats
# 30       122                6      3        646.0           79  refined oil
# 31       122                6      4        821.0          133    dantkanti
# 32       122                6      5        222.0           57        maida
# 33       122                6      6        456.0           92        besan
# 34       122                6      7        413.5           51    dantkanti
# 35       122                6      8        575.5          114        maida
# 36       123                7      3        201.5           56  clinic plus
# 37       123                7      4        795.0          107        sugar
# 38       123                7      5        840.0          155  refined oil
# 39       123                7      6       1947.5          222     nutrella
# 40       123                7      7        472.0           40  quaker oats
# 41       123                7      8        362.0           43        sugar
# 42       123                8      3        675.5           62  clinic plus
# 43       123                8      4       1017.5           95    dantkanti
# 44       123                8      5       1400.0          205    dantkanti
# 45       123                8      6       1489.5          168        sugar
# 46       123                8      7       1156.0          245        maida
# 47       123                8      8        736.0          109  quaker oats
# 48       123                9      3        725.5           97  quaker oats
# 49       123                9      4        293.0           85  clinic plus
# 50       123                9      5        904.0          106        sugar
# 51       123                9      6        608.5           64  refined oil
# 52       123                9      7        532.0           87    dantkanti
# 53       123                9      8        375.5           52        maida
#
#     quantity   bonus
# 0          4   0.000
# 1          5   0.000
# 2         10   0.000
# 3          4  12.615
# 4          8   0.000
# 5          3  11.600
# 6          1   7.860
# 7         10   0.000
# 8          9   0.000
# 9          7   0.000
# 10         7   0.000
# 11         7   0.000
# 12         8   0.000
# 13         3   8.195
# 14         4   7.900
# 15        10   0.000
# 16        10  15.465
# 17         2   0.000
# 18         6   0.000
# 19         3   0.000
# 20         8   0.000
# 21         5   0.000
# 22         2   8.470
# 23         3   0.000
# 24        10   7.320
# 25        10   0.000
# 26        10   4.260
# 27         1   8.135
# 28        10   0.000
# 29         9   5.760
# 30         3   0.000
# 31         3   8.210
# 32         4   0.000
# 33         9   0.000
# 34         9   0.000
# 35         1   0.000
# 36         5   0.000
# 37         9   0.000
# 38         5   0.000
# 39         9  19.475
# 40         4   0.000
# 41         8   0.000
# 42        10   0.000
# 43         2  10.175
# 44        10  14.000
# 45         5   0.000
# 46         4  11.560
# 47         7   7.360
# 48         5   7.255
# 49         7   0.000
# 50         9   0.000
# 51         3   0.000
# 52         8   0.000
# 53         1   0.000

# %%
sales_dm = pd.merge(result2,df_sales, left_on='sales_person_id', right_on='id', how = 'inner')

# %%
sales_dm['full_name'] = sales_dm['first_name']+' '+sales_dm['last_name']

# %%
sales_dm.columns
# Out:
# Index(['store_id', 'sales_person_id', 'month', 'total_sales', 'customer_id',
#        'product_name', 'quantity', 'bonus', 'id', 'first_name', 'last_name',
#        'manager_id', 'is_manager', 'address', 'pincode', 'joining_date',
#        'full_name'],
#       dtype='object')

# %%
sales_dm = sales_dm[['store_id', 'sales_person_id','full_name', 'month', 'total_sales','bonus'
       ]]

# %%
sales_dm = sales_dm.sort_values(by= ['store_id', 'month','bonus'], ascending=[True,True,False])

# %%
sales_dm = sales_dm.rename(columns={'month':'sales_month', 'bonus':'incentive'})

# %%
sales_dm.head()
# Out:
#     store_id  sales_person_id    full_name  sales_month  total_sales  \
# 6        121                2  Priya Singh            3        786.0
# 0        121                1  Rahul Verma            3        206.5
# 12       121                3  Amit Sharma            3        396.0
# 13       121                3  Amit Sharma            4        819.5
# 1        121                1  Rahul Verma            4        535.0
#
#     incentive
# 6       7.860
# 0       0.000
# 12      0.000
# 13      8.195
# 1       0.000

# %%
#!pip install mysqlclient

# %%
sales_dm.to_sql('sales_team_data_mart', con=engine, if_exists='replace', index=False)
# Out:
# 54

# %%
#sales_dm.to_csv("sales_team_datamart.csv", index=False)

# %%
f_to_upload2 = "C:\\Users\\aman.ab.srivastava\\Documents\\pro\\data\\sales_datamart\\sales_team_datamart.csv"
# blob_client2 = blob_service_client.get_blob_client(container_name, "sales_team_datamart.csv")
# with open(f_to_upload2, "rb") as data:
#     blob_client2.upload_blob(data, overwrite=True)
    
blob_helper.upload_file(config.container_name, f_to_upload2, "sales_team_datamart.csv")
# Out:
# 'file uploaded successfully'

# %%
#cust_dm.to_csv("customers_datamart.csv", index=False)

# %%
f_to_upload3 = "C:\\Users\\aman.ab.srivastava\\Documents\\pro\\data\\customer_datamart\\customers_datamart.csv"

# %%
blob_helper.upload_file(config.container_name, f_to_upload3, "customers_datamart.csv")
# Out:
# 'file uploaded successfully'
